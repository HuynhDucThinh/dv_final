# %% [markdown]
# # 📊 01 — Khám phá dữ liệu (Exploratory Data Analysis)
#
# **Mục tiêu:**
# - Tìm hiểu cấu trúc bộ dữ liệu
# - Phát hiện giá trị thiếu, ngoại lệ (outliers)
# - Phân tích phân phối các biến
# - Tìm mối tương quan giữa các biến
#
# **Ngày tạo:** 2026-07-02

# %%
# ============================================================
# IMPORT THƯ VIỆN
# ============================================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

# %matplotlib inline
print('✅ Thư viện đã được import thành công!')

# %%
# ============================================================
# TẢI DỮ LIỆU
# ============================================================
DATA_PATH = '../data/raw/'  # Thay đổi đường dẫn nếu cần

# df = pd.read_csv(DATA_PATH + 'your_file.csv')
# df = pd.read_excel(DATA_PATH + 'your_file.xlsx')

# --- Demo với dữ liệu mẫu ---
np.random.seed(42)
df = pd.DataFrame({
    'id': range(1, 101),
    'category': np.random.choice(['A', 'B', 'C'], 100),
    'value': np.random.normal(50, 15, 100).round(2),
    'score': np.random.randint(0, 100, 100),
    'date': pd.date_range('2025-01-01', periods=100, freq='D')
})

print(f'Shape: {df.shape}')
df.head()

# %%
# ============================================================
# THÔNG TIN TỔNG QUAN
# ============================================================
print('=== THÔNG TIN CƠ BẢN ===')
print(df.info())
print('\n=== THỐNG KÊ MÔ TẢ ===')
display(df.describe())
print('\n=== GIÁ TRỊ THIẾU ===')
missing = df.isnull().sum()
print(missing[missing > 0] if missing.sum() > 0 else 'Không có giá trị thiếu ✅')

# %%
# ============================================================
# PHÂN PHỐI CÁC BIẾN SỐ
# ============================================================
numeric_cols = df.select_dtypes(include='number').columns.tolist()
fig, axes = plt.subplots(1, len(numeric_cols), figsize=(5 * len(numeric_cols), 4))

for i, col in enumerate(numeric_cols):
    ax = axes[i] if len(numeric_cols) > 1 else axes
    sns.histplot(df[col], kde=True, ax=ax, color='steelblue')
    ax.set_title(f'Phân phối: {col}')

plt.tight_layout()
plt.savefig('../report/figures/01_distribution.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================
# MA TRẬN TƯƠNG QUAN
# ============================================================
corr_matrix = df[numeric_cols].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm',
            center=0, linewidths=0.5)
plt.title('Ma trận tương quan', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('../report/figures/01_correlation.png', dpi=150, bbox_inches='tight')
plt.show()
